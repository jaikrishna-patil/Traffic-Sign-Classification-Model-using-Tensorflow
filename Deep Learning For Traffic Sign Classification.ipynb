# %% [markdown]
# # TASK #1: PROJECT OVERVIEW

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES/DATASETS

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']

# %%
X_test, y_test = test['features'], test['labels']

# %%
X_validation, y_validation = valid['features'], valid['labels']

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
y_test.shape
# Out:
# (12630,)

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
y_validation.shape
# Out:
# (4410,)

# %% [markdown]
# # TASK #3: PERFORM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 7

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 10
L_grid = 10

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (40,40))

axes = axes.ravel() # flaten the 5 x 5 matrix into 25 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
# create evenly spaces variables 
# Select a random number
# read and display an image with the selected index    

for i in np.arange(0,W_grid*L_grid):
    
    index= np.random.randint(0, n_training)
    
    axes[i].imshow(X_train[index])
    axes[i].set_title(y_train[index],fontsize=20)
    axes[i].axis('off')

# %% [markdown]
# # TASK #4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray= np.sum(X_train/3,axis=3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_train_gray_norm=(X_train_gray-128)/128

# %%
X_train_gray_norm #-1 to +1
# Out:
# array([[[[-0.50260417],
#          [-0.54427083],
#          [-0.546875  ],
#          ...,
#          [-0.55729167],
#          [-0.53125   ],
#          [-0.68489583]],
#
#         [[-0.40885417],
#          [-0.44791667],
#          [-0.52604167],
#          ...,
#          [-0.578125  ],
#          [-0.52864583],
#          [-0.5859375 ]],
#
#         [[-0.36979167],
#          [-0.3984375 ],
#          [-0.51302083],
#          ...,
#          [-0.63541667],
#          [-0.5703125 ],
#          [-0.57552083]],
#
#         ...,
#
#         [[-0.32291667],
#          [-0.38020833],
#          [-0.52604167],
#          ...,
#          [-0.65885417],
#          [-0.5       ],
#          [-0.5078125 ]],
#
#         [[-0.34375   ],
#          [-0.36979167],
#          [-0.42447917],
#          ...,
#          [-0.65885417],
#          [-0.51041667],
#          [-0.5078125 ]],
#
#         [[-0.40625   ],
#          [-0.40885417],
#          [-0.41666667],
#          ...,
#          [-0.66666667],
#          [-0.52864583],
#          [-0.5234375 ]]],
#
#
#        [[[-0.42447917],
#          [-0.47916667],
#          [-0.43229167],
#          ...,
#          [-0.37239583],
#          [-0.47916667],
#          [-0.4453125 ]],
#
#         [[-0.45052083],
#          [-0.43229167],
#          [-0.33333333],
#          ...,
#          [-0.33854167],
#          [-0.515625  ],
#          [-0.4765625 ]],
#
#         [[-0.3515625 ],
#          [-0.31510417],
#          [-0.26041667],
#          ...,
#          [-0.42447917],
#          [-0.5390625 ],
#          [-0.52604167]],
#
#         ...,
#
#         [[-0.296875  ],
#          [-0.36197917],
#          [-0.38541667],
#          ...,
#          [-0.59635417],
#          [-0.6484375 ],
#          [-0.65625   ]],
#
#         [[-0.2421875 ],
#          [-0.34375   ],
#          [-0.34895833],
#          ...,
#          [-0.59635417],
#          [-0.63020833],
#          [-0.6328125 ]],
#
#         [[-0.30208333],
#          [-0.34895833],
#          [-0.37760417],
#          ...,
#          [-0.58333333],
#          [-0.61979167],
#          [-0.63541667]]],
#
#
#        [[[-0.41666667],
#          [-0.3984375 ],
#          [-0.2890625 ],
#          ...,
#          [-0.43229167],
#          [-0.38541667],
#          [-0.43489583]],
#
#         [[-0.35416667],
#          [-0.3359375 ],
#          [-0.33072917],
#          ...,
#          [-0.45052083],
#          [-0.28125   ],
#          [-0.29427083]],
#
#         [[-0.34635417],
#          [-0.31770833],
#          [-0.3515625 ],
#          ...,
#          [-0.33072917],
#          [-0.26302083],
#          [-0.24479167]],
#
#         ...,
#
#         [[-0.14583333],
#          [ 0.01822917],
#          [ 0.30989583],
#          ...,
#          [-0.2109375 ],
#          [-0.22135417],
#          [-0.24479167]],
#
#         [[-0.18229167],
#          [-0.15364583],
#          [-0.12760417],
#          ...,
#          [-0.20572917],
#          [-0.20052083],
#          [-0.19791667]],
#
#         [[-0.19010417],
#          [-0.17447917],
#          [-0.171875  ],
#          ...,
#          [-0.21875   ],
#          [-0.19270833],
#          [-0.1953125 ]]],
#
#
#        ...,
#
#
#        [[[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         ...,
#
#         [[-0.65625   ],
#          [-0.64583333],
#          [-0.64583333],
#          ...,
#          [-0.71354167],
#          [-0.71614583],
#          [-0.72395833]],
#
#         [[-0.640625  ],
#          [-0.640625  ],
#          [-0.6484375 ],
#          ...,
#          [-0.71354167],
#          [-0.72135417],
#          [-0.70833333]],
#
#         [[-0.6484375 ],
#          [-0.65104167],
#          [-0.65625   ],
#          ...,
#          [-0.7265625 ],
#          [-0.72135417],
#          [-0.6953125 ]]],
#
#
#        [[[-0.25260417],
#          [-0.1875    ],
#          [-0.26822917],
#          ...,
#          [-0.83072917],
#          [-0.84114583],
#          [-0.83333333]],
#
#         [[-0.32552083],
#          [-0.40364583],
#          [-0.53385417],
#          ...,
#          [-0.83072917],
#          [-0.83333333],
#          [-0.8515625 ]],
#
#         [[-0.5078125 ],
#          [-0.52604167],
#          [-0.56770833],
#          ...,
#          [-0.8359375 ],
#          [-0.8671875 ],
#          [-0.86979167]],
#
#         ...,
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.87239583],
#          ...,
#          [-0.546875  ],
#          [-0.59114583],
#          [-0.62239583]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.98697917],
#          ...,
#          [-0.67447917],
#          [-0.62239583],
#          [-0.58854167]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [-0.65885417],
#          [-0.61979167],
#          [-0.55729167]]],
#
#
#        [[[ 0.26302083],
#          [ 0.26302083],
#          [ 0.27083333],
#          ...,
#          [ 0.25      ],
#          [ 0.26822917],
#          [ 0.26302083]],
#
#         [[ 0.2421875 ],
#          [ 0.24739583],
#          [ 0.2578125 ],
#          ...,
#          [ 0.2265625 ],
#          [ 0.26302083],
#          [ 0.25520833]],
#
#         [[ 0.2421875 ],
#          [ 0.23958333],
#          [ 0.24479167],
#          ...,
#          [ 0.05729167],
#          [ 0.234375  ],
#          [ 0.23958333]],
#
#         ...,
#
#         [[-0.63802083],
#          [-0.63802083],
#          [-0.5859375 ],
#          ...,
#          [-0.546875  ],
#          [-0.56510417],
#          [-0.58854167]],
#
#         [[-0.63020833],
#          [-0.62239583],
#          [-0.5703125 ],
#          ...,
#          [-0.56770833],
#          [-0.58854167],
#          [-0.6015625 ]],
#
#         [[-0.625     ],
#          [-0.64322917],
#          [-0.6015625 ],
#          ...,
#          [-0.58854167],
#          [-0.63020833],
#          [-0.63541667]]]])

# %%
#Test

# %%
X_test, y_test = shuffle(X_test, y_test)

# %%
X_test_gray= np.sum(X_test/3,axis=3, keepdims = True)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_test_gray_norm=(X_test_gray-128)/128

# %%
X_test_gray_norm #-1 to +1
# Out:
# array([[[[ 0.953125  ],
#          [ 0.91927083],
#          [ 0.89583333],
#          ...,
#          [-0.48958333],
#          [-0.4921875 ],
#          [-0.52083333]],
#
#         [[ 0.95572917],
#          [ 0.92447917],
#          [ 0.89583333],
#          ...,
#          [-0.47135417],
#          [-0.4921875 ],
#          [-0.53125   ]],
#
#         [[ 0.94791667],
#          [ 0.91145833],
#          [ 0.88802083],
#          ...,
#          [-0.53385417],
#          [-0.50520833],
#          [-0.54166667]],
#
#         ...,
#
#         [[ 0.96614583],
#          [ 0.94270833],
#          [ 0.92447917],
#          ...,
#          [-0.41666667],
#          [-0.39583333],
#          [-0.24739583]],
#
#         [[ 0.96354167],
#          [ 0.9140625 ],
#          [ 0.9140625 ],
#          ...,
#          [-0.41927083],
#          [-0.42447917],
#          [-0.30208333]],
#
#         [[ 0.95833333],
#          [ 0.90104167],
#          [ 0.90625   ],
#          ...,
#          [-0.41145833],
#          [-0.4140625 ],
#          [-0.30208333]]],
#
#
#        [[[ 0.46875   ],
#          [ 0.5078125 ],
#          [ 0.50260417],
#          ...,
#          [ 0.6875    ],
#          [ 0.66927083],
#          [ 0.66666667]],
#
#         [[ 0.515625  ],
#          [ 0.5546875 ],
#          [ 0.56770833],
#          ...,
#          [ 0.73958333],
#          [ 0.73958333],
#          [ 0.73697917]],
#
#         [[ 0.53125   ],
#          [ 0.57552083],
#          [ 0.5625    ],
#          ...,
#          [ 0.6796875 ],
#          [ 0.71614583],
#          [ 0.75260417]],
#
#         ...,
#
#         [[-0.81770833],
#          [-0.79166667],
#          [-0.80989583],
#          ...,
#          [ 0.19010417],
#          [ 0.1328125 ],
#          [ 0.01822917]],
#
#         [[-0.8359375 ],
#          [-0.8203125 ],
#          [-0.83072917],
#          ...,
#          [ 0.06510417],
#          [-0.04427083],
#          [-0.1796875 ]],
#
#         [[-0.82291667],
#          [-0.81510417],
#          [-0.80208333],
#          ...,
#          [-0.02604167],
#          [-0.203125  ],
#          [-0.390625  ]]],
#
#
#        [[[ 0.08072917],
#          [ 0.07552083],
#          [ 0.0546875 ],
#          ...,
#          [ 0.0859375 ],
#          [ 0.0703125 ],
#          [ 0.07552083]],
#
#         [[ 0.08333333],
#          [ 0.078125  ],
#          [ 0.08333333],
#          ...,
#          [ 0.06770833],
#          [ 0.07291667],
#          [ 0.0859375 ]],
#
#         [[ 0.08072917],
#          [ 0.07291667],
#          [ 0.07291667],
#          ...,
#          [ 0.078125  ],
#          [ 0.06770833],
#          [ 0.07291667]],
#
#         ...,
#
#         [[-0.80729167],
#          [-0.8125    ],
#          [-0.8203125 ],
#          ...,
#          [-0.80989583],
#          [-0.81770833],
#          [-0.80729167]],
#
#         [[-0.8125    ],
#          [-0.81770833],
#          [-0.83333333],
#          ...,
#          [-0.81510417],
#          [-0.81770833],
#          [-0.81510417]],
#
#         [[-0.81510417],
#          [-0.8203125 ],
#          [-0.84114583],
#          ...,
#          [-0.8203125 ],
#          [-0.828125  ],
#          [-0.82552083]]],
#
#
#        ...,
#
#
#        [[[-0.69270833],
#          [-0.71614583],
#          [-0.7265625 ],
#          ...,
#          [-0.82552083],
#          [-0.82552083],
#          [-0.83072917]],
#
#         [[-0.81510417],
#          [-0.81510417],
#          [-0.81510417],
#          ...,
#          [-0.80208333],
#          [-0.80208333],
#          [-0.79947917]],
#
#         [[-0.8046875 ],
#          [-0.80729167],
#          [-0.80208333],
#          ...,
#          [-0.66666667],
#          [-0.63802083],
#          [-0.66666667]],
#
#         ...,
#
#         [[-0.66145833],
#          [-0.68489583],
#          [-0.70052083],
#          ...,
#          [-0.87760417],
#          [-0.8828125 ],
#          [-0.8828125 ]],
#
#         [[-0.65104167],
#          [-0.6796875 ],
#          [-0.72916667],
#          ...,
#          [-0.87239583],
#          [-0.88541667],
#          [-0.8828125 ]],
#
#         [[-0.65104167],
#          [-0.68489583],
#          [-0.71614583],
#          ...,
#          [-0.87760417],
#          [-0.8828125 ],
#          [-0.88020833]]],
#
#
#        [[[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [ 0.98697917],
#          [ 0.98177083],
#          [ 0.98697917]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.9921875 ],
#          ...,
#          [ 0.98177083],
#          [ 0.97395833],
#          [ 0.98177083]],
#
#         ...,
#
#         [[ 0.57291667],
#          [ 0.25520833],
#          [ 0.52083333],
#          ...,
#          [ 0.68229167],
#          [ 0.8515625 ],
#          [ 0.84895833]],
#
#         [[-0.14322917],
#          [-0.10677083],
#          [ 0.20052083],
#          ...,
#          [ 0.671875  ],
#          [ 0.82552083],
#          [ 0.84375   ]],
#
#         [[-0.3359375 ],
#          [-0.1640625 ],
#          [-0.05208333],
#          ...,
#          [ 0.65364583],
#          [ 0.8046875 ],
#          [ 0.85416667]]],
#
#
#        [[[-0.890625  ],
#          [-0.89322917],
#          [-0.90104167],
#          ...,
#          [-0.72916667],
#          [-0.44270833],
#          [-0.34895833]],
#
#         [[-0.890625  ],
#          [-0.90104167],
#          [-0.90885417],
#          ...,
#          [-0.76302083],
#          [-0.5234375 ],
#          [-0.50520833]],
#
#         [[-0.890625  ],
#          [-0.90104167],
#          [-0.90885417],
#          ...,
#          [-0.7734375 ],
#          [-0.6796875 ],
#          [-0.54166667]],
#
#         ...,
#
#         [[-0.890625  ],
#          [-0.89322917],
#          [-0.90364583],
#          ...,
#          [-0.8828125 ],
#          [-0.91145833],
#          [-0.90625   ]],
#
#         [[-0.9140625 ],
#          [-0.90104167],
#          [-0.90625   ],
#          ...,
#          [-0.88541667],
#          [-0.91666667],
#          [-0.921875  ]],
#
#         [[-0.91666667],
#          [-0.91145833],
#          [-0.90885417],
#          ...,
#          [-0.88541667],
#          [-0.90885417],
#          [-0.90625   ]]]])

# %%
#Validation

# %%
X_validation, y_validation = shuffle(X_validation, y_validation)

# %%
X_validation_gray= np.sum(X_validation/3,axis=3, keepdims = True)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_validation_gray_norm=(X_validation_gray-128)/128

# %%
X_validation_gray_norm #-1 to +1
# Out:
# array([[[[ 0.67708333],
#          [ 0.67447917],
#          [ 0.66927083],
#          ...,
#          [ 0.66927083],
#          [ 0.59895833],
#          [ 0.45572917]],
#
#         [[ 0.6796875 ],
#          [ 0.67708333],
#          [ 0.66666667],
#          ...,
#          [ 0.6640625 ],
#          [ 0.66145833],
#          [ 0.64583333]],
#
#         [[ 0.68229167],
#          [ 0.6796875 ],
#          [ 0.68489583],
#          ...,
#          [ 0.65364583],
#          [ 0.65364583],
#          [ 0.65625   ]],
#
#         ...,
#
#         [[-0.75260417],
#          [-0.7109375 ],
#          [-0.67708333],
#          ...,
#          [-0.36458333],
#          [-0.29427083],
#          [-0.32291667]],
#
#         [[-0.74479167],
#          [-0.70052083],
#          [-0.6796875 ],
#          ...,
#          [-0.42447917],
#          [-0.38802083],
#          [-0.38802083]],
#
#         [[-0.72395833],
#          [-0.70572917],
#          [-0.6953125 ],
#          ...,
#          [-0.51302083],
#          [-0.45052083],
#          [-0.42708333]]],
#
#
#        [[[-0.45833333],
#          [-0.41927083],
#          [-0.51822917],
#          ...,
#          [-0.12760417],
#          [-0.17708333],
#          [-0.0078125 ]],
#
#         [[-0.4296875 ],
#          [-0.39322917],
#          [-0.484375  ],
#          ...,
#          [ 0.        ],
#          [-0.15364583],
#          [-0.19270833]],
#
#         [[-0.38802083],
#          [-0.37760417],
#          [-0.45572917],
#          ...,
#          [ 0.23177083],
#          [ 0.02604167],
#          [-0.03385417]],
#
#         ...,
#
#         [[-0.52864583],
#          [-0.53645833],
#          [-0.41927083],
#          ...,
#          [-0.08854167],
#          [-0.05208333],
#          [-0.01822917]],
#
#         [[-0.40625   ],
#          [-0.58854167],
#          [-0.63020833],
#          ...,
#          [ 0.10416667],
#          [-0.03125   ],
#          [-0.15104167]],
#
#         [[-0.38802083],
#          [-0.55729167],
#          [-0.50520833],
#          ...,
#          [ 0.33072917],
#          [ 0.        ],
#          [-0.25520833]]],
#
#
#        [[[-0.64322917],
#          [-0.671875  ],
#          [-0.6015625 ],
#          ...,
#          [-0.265625  ],
#          [-0.53385417],
#          [-0.49479167]],
#
#         [[-0.640625  ],
#          [-0.6640625 ],
#          [-0.59635417],
#          ...,
#          [-0.2890625 ],
#          [-0.5390625 ],
#          [-0.48958333]],
#
#         [[-0.64583333],
#          [-0.66927083],
#          [-0.61197917],
#          ...,
#          [-0.28385417],
#          [-0.5234375 ],
#          [-0.5       ]],
#
#         ...,
#
#         [[-0.02083333],
#          [-0.53125   ],
#          [-0.6484375 ],
#          ...,
#          [-0.02864583],
#          [-0.546875  ],
#          [-0.56770833]],
#
#         [[-0.015625  ],
#          [-0.47395833],
#          [-0.6015625 ],
#          ...,
#          [-0.58333333],
#          [-0.63541667],
#          [-0.60677083]],
#
#         [[-0.10677083],
#          [-0.47395833],
#          [-0.609375  ],
#          ...,
#          [-0.62239583],
#          [-0.62239583],
#          [-0.44010417]]],
#
#
#        ...,
#
#
#        [[[-0.875     ],
#          [-0.875     ],
#          [-0.87239583],
#          ...,
#          [-0.89583333],
#          [-0.90625   ],
#          [-0.90625   ]],
#
#         [[-0.87239583],
#          [-0.88020833],
#          [-0.88541667],
#          ...,
#          [-0.90104167],
#          [-0.90364583],
#          [-0.890625  ]],
#
#         [[-0.87760417],
#          [-0.875     ],
#          [-0.87760417],
#          ...,
#          [-0.90364583],
#          [-0.89583333],
#          [-0.8984375 ]],
#
#         ...,
#
#         [[-0.77864583],
#          [-0.7734375 ],
#          [-0.77083333],
#          ...,
#          [-0.7421875 ],
#          [-0.73958333],
#          [-0.70833333]],
#
#         [[-0.7890625 ],
#          [-0.78125   ],
#          [-0.7734375 ],
#          ...,
#          [-0.74739583],
#          [-0.7421875 ],
#          [-0.71614583]],
#
#         [[-0.80729167],
#          [-0.79427083],
#          [-0.78645833],
#          ...,
#          [-0.75260417],
#          [-0.73697917],
#          [-0.71614583]]],
#
#
#        [[[-0.23697917],
#          [-0.13541667],
#          [-0.11197917],
#          ...,
#          [-0.02083333],
#          [ 0.27083333],
#          [ 0.42447917]],
#
#         [[-0.21354167],
#          [-0.12760417],
#          [-0.11197917],
#          ...,
#          [ 0.76302083],
#          [ 0.90364583],
#          [ 0.96354167]],
#
#         [[-0.2265625 ],
#          [-0.12760417],
#          [-0.10416667],
#          ...,
#          [ 0.7890625 ],
#          [ 0.84114583],
#          [ 0.83072917]],
#
#         ...,
#
#         [[-0.48177083],
#          [-0.55729167],
#          [-0.55208333],
#          ...,
#          [-0.4765625 ],
#          [-0.4921875 ],
#          [-0.5234375 ]],
#
#         [[-0.53125   ],
#          [-0.5703125 ],
#          [-0.48697917],
#          ...,
#          [-0.56770833],
#          [-0.55729167],
#          [-0.5390625 ]],
#
#         [[-0.48958333],
#          [-0.44010417],
#          [-0.38020833],
#          ...,
#          [-0.58072917],
#          [-0.52604167],
#          [-0.52083333]]],
#
#
#        [[[ 0.05729167],
#          [ 0.05989583],
#          [ 0.046875  ],
#          ...,
#          [ 0.078125  ],
#          [ 0.06510417],
#          [ 0.1015625 ]],
#
#         [[ 0.04166667],
#          [ 0.0390625 ],
#          [ 0.04947917],
#          ...,
#          [ 0.07552083],
#          [ 0.0703125 ],
#          [ 0.1015625 ]],
#
#         [[ 0.05729167],
#          [ 0.046875  ],
#          [ 0.04427083],
#          ...,
#          [ 0.07552083],
#          [ 0.078125  ],
#          [ 0.09895833]],
#
#         ...,
#
#         [[-0.83854167],
#          [-0.84114583],
#          [-0.8359375 ],
#          ...,
#          [-0.76302083],
#          [-0.7109375 ],
#          [-0.64583333]],
#
#         [[-0.84114583],
#          [-0.84375   ],
#          [-0.83854167],
#          ...,
#          [-0.72135417],
#          [-0.671875  ],
#          [-0.66666667]],
#
#         [[-0.83854167],
#          [-0.8359375 ],
#          [-0.83072917],
#          ...,
#          [-0.6953125 ],
#          [-0.72916667],
#          [-0.75520833]]]])

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # TASK #5: UNDERSTAND THE THEORY AND INTUITION BEHIND CONVOLUTIONAL NEURAL NETWORKS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #6: BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models


CNN=models.Sequential()

CNN.add(layers.Conv2D(6, (5,5), activation= 'relu', input_shape=(32,32,1)))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Conv2D(16, (5,5), activation= 'relu'))
CNN.add(layers.AveragePooling2D())
CNN.add(layers.Dropout(0.2, seed=321))

CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation='relu'))
CNN.add(layers.Dense(84, activation='relu'))
CNN.add(layers.Dense(43, activation='softmax'))

CNN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # TASK #7: COMPILE AND TRAIN DEEP CNN MODEL

# %%
CNN.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history= CNN.fit(X_train_gray_norm,
              y_train,
                verbose=1,
                epochs=50,
                batch_size= 500,
                validation_data=(X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 5s 67ms/step - loss: 3.2608 - accuracy: 0.1441 - val_loss: 2.7909 - val_accuracy: 0.2667
# Epoch 2/50
# 70/70 [==============================] - 4s 62ms/step - loss: 1.7658 - accuracy: 0.5057 - val_loss: 1.2662 - val_accuracy: 0.6472
# Epoch 3/50
# 70/70 [==============================] - 4s 60ms/step - loss: 0.9450 - accuracy: 0.7208 - val_loss: 0.8480 - val_accuracy: 0.7413
# Epoch 4/50
# 70/70 [==============================] - 4s 60ms/step - loss: 0.6971 - accuracy: 0.7950 - val_loss: 0.7021 - val_accuracy: 0.7803
# Epoch 5/50
# 70/70 [==============================] - 4s 61ms/step - loss: 0.5571 - accuracy: 0.8393 - val_loss: 0.6269 - val_accuracy: 0.8129
# Epoch 6/50
# 70/70 [==============================] - 4s 62ms/step - loss: 0.4703 - accuracy: 0.8653 - val_loss: 0.5600 - val_accuracy: 0.8345
# Epoch 7/50
# 70/70 [==============================] - 4s 64ms/step - loss: 0.4080 - accuracy: 0.8842 - val_loss: 0.5402 - val_accuracy: 0.8365
# Epoch 8/50
# 70/70 [==============================] - 4s 62ms/step - loss: 0.3695 - accuracy: 0.8965 - val_loss: 0.4924 - val_accuracy: 0.8574
# Epoch 9/50
# 70/70 [==============================] - 4s 62ms/step - loss: 0.3292 - accuracy: 0.9084 - val_loss: 0.4794 - val_accuracy: 0.8601
# Epoch 10/50
# 70/70 [==============================] - 4s 62ms/step - loss: 0.2961 - accuracy: 0.9184 - val_loss: 0.4515 - val_accuracy: 0.8612
# Epoch 11/50
# 70/70 [==============================] - 4s 63ms/step - loss: 0.2730 - accuracy: 0.9240 - val_loss: 0.4482 - val_accuracy: 0.8590
# Epoch 12/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.2493 - accuracy: 0.9310 - val_loss: 0.4161 - val_accuracy: 0.8757
# Epoch 13/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.2311 - accuracy: 0.9360 - val_loss: 0.4136 - val_accuracy: 0.8660
# Epoch 14/50
# 70/70 [==============================] - 4s 63ms/step - loss: 0.2180 - accuracy: 0.9400 - val_loss: 0.3847 - val_accuracy: 0.8923
# Epoch 15/50
# 70/70 [==============================] - 4s 64ms/step - loss: 0.1983 - accuracy: 0.9446 - val_loss: 0.3926 - val_accuracy: 0.8853
# Epoch 16/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.1886 - accuracy: 0.9477 - val_loss: 0.3815 - val_accuracy: 0.8848
# Epoch 17/50
# 70/70 [==============================] - 5s 64ms/step - loss: 0.1778 - accuracy: 0.9511 - val_loss: 0.3819 - val_accuracy: 0.8909
# Epoch 18/50
# 70/70 [==============================] - 4s 64ms/step - loss: 0.1687 - accuracy: 0.9531 - val_loss: 0.3783 - val_accuracy: 0.8921
# Epoch 19/50
# 70/70 [==============================] - 5s 66ms/step - loss: 0.1583 - accuracy: 0.9555 - val_loss: 0.3975 - val_accuracy: 0.8837
# Epoch 20/50
# 70/70 [==============================] - 4s 64ms/step - loss: 0.1499 - accuracy: 0.9592 - val_loss: 0.3259 - val_accuracy: 0.9122
# Epoch 21/50
# 70/70 [==============================] - 4s 64ms/step - loss: 0.1424 - accuracy: 0.9602 - val_loss: 0.3862 - val_accuracy: 0.8909
# Epoch 22/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.1315 - accuracy: 0.9629 - val_loss: 0.3317 - val_accuracy: 0.9005
# Epoch 23/50
# 70/70 [==============================] - 5s 66ms/step - loss: 0.1219 - accuracy: 0.9669 - val_loss: 0.3595 - val_accuracy: 0.8995
# Epoch 24/50
# 70/70 [==============================] - 5s 66ms/step - loss: 0.1217 - accuracy: 0.9651 - val_loss: 0.3610 - val_accuracy: 0.9020
# Epoch 25/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.1153 - accuracy: 0.9680 - val_loss: 0.3578 - val_accuracy: 0.9061
# Epoch 26/50
# 70/70 [==============================] - 5s 67ms/step - loss: 0.1087 - accuracy: 0.9699 - val_loss: 0.3754 - val_accuracy: 0.9005
# Epoch 27/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.1047 - accuracy: 0.9708 - val_loss: 0.3516 - val_accuracy: 0.9057
# Epoch 28/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.1051 - accuracy: 0.9699 - val_loss: 0.3242 - val_accuracy: 0.9163
# Epoch 29/50
# 70/70 [==============================] - 5s 66ms/step - loss: 0.0995 - accuracy: 0.9710 - val_loss: 0.3372 - val_accuracy: 0.9079
# Epoch 30/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.0929 - accuracy: 0.9723 - val_loss: 0.3632 - val_accuracy: 0.9043
# Epoch 31/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.0933 - accuracy: 0.9727 - val_loss: 0.3509 - val_accuracy: 0.9093
# Epoch 32/50
# 70/70 [==============================] - 5s 66ms/step - loss: 0.0861 - accuracy: 0.9760 - val_loss: 0.3530 - val_accuracy: 0.9143
# Epoch 33/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.0813 - accuracy: 0.9773 - val_loss: 0.3505 - val_accuracy: 0.9127
# Epoch 34/50
# 70/70 [==============================] - 5s 65ms/step - loss: 0.0796 - accuracy: 0.9770 - val_loss: 0.3247 - val_accuracy: 0.9204
# Epoch 35/50
# 70/70 [==============================] - 5s 69ms/step - loss: 0.0783 - accuracy: 0.9779 - val_loss: 0.3519 - val_accuracy: 0.9161
# Epoch 36/50
# 70/70 [==============================] - 5s 70ms/step - loss: 0.0720 - accuracy: 0.9795 - val_loss: 0.3675 - val_accuracy: 0.9109
# Epoch 37/50
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0701 - accuracy: 0.9795 - val_loss: 0.3162 - val_accuracy: 0.9229
# Epoch 38/50
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0672 - accuracy: 0.9799 - val_loss: 0.2951 - val_accuracy: 0.9268
# Epoch 39/50
# 70/70 [==============================] - 5s 74ms/step - loss: 0.0703 - accuracy: 0.9797 - val_loss: 0.3683 - val_accuracy: 0.9050
# Epoch 40/50
# 70/70 [==============================] - 5s 69ms/step - loss: 0.0651 - accuracy: 0.9805 - val_loss: 0.3325 - val_accuracy: 0.9122
# Epoch 41/50
# 70/70 [==============================] - 5s 70ms/step - loss: 0.0602 - accuracy: 0.9828 - val_loss: 0.3563 - val_accuracy: 0.9113
# Epoch 42/50
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0598 - accuracy: 0.9823 - val_loss: 0.3815 - val_accuracy: 0.9075
# Epoch 43/50
# 70/70 [==============================] - 5s 67ms/step - loss: 0.0590 - accuracy: 0.9827 - val_loss: 0.3374 - val_accuracy: 0.9111
# Epoch 44/50
# 70/70 [==============================] - 5s 69ms/step - loss: 0.0588 - accuracy: 0.9828 - val_loss: 0.3674 - val_accuracy: 0.9107
# Epoch 45/50
# 70/70 [==============================] - 5s 73ms/step - loss: 0.0575 - accuracy: 0.9831 - val_loss: 0.2911 - val_accuracy: 0.9188
# Epoch 46/50
# 70/70 [==============================] - 5s 73ms/step - loss: 0.0533 - accuracy: 0.9836 - val_loss: 0.3289 - val_accuracy: 0.9132
# Epoch 47/50
# 70/70 [==============================] - 5s 71ms/step - loss: 0.0453 - accuracy: 0.9864 - val_loss: 0.3339 - val_accuracy: 0.9154
# Epoch 48/50
# 70/70 [==============================] - 5s 71ms/step - loss: 0.0484 - accuracy: 0.9861 - val_loss: 0.3539 - val_accuracy: 0.9129
# Epoch 49/50
# 70/70 [==============================] - 5s 71ms/step - loss: 0.0517 - accuracy: 0.9840 - val_loss: 0.3523 - val_accuracy: 0.9209
# Epoch 50/50
# 70/70 [==============================] - 5s 70ms/step - loss: 0.0472 - accuracy: 0.9857 - val_loss: 0.3258 - val_accuracy: 0.9234

# %% [markdown]
# # TASK #8: ASSESS TRAINED CNN MODEL PERFORMANCE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.5300 - accuracy: 0.9116
# Test Accuracy: 0.9115597605705261

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs= range(len(accuracy))

# %%
plt.plot(epochs, loss, 'ro', label= 'Training loss')
plt.plot(epochs, val_loss, 'r', label= 'validation loss')

# %%
plt.plot(epochs, accuracy, 'ro', label= 'Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label= 'validation accuracy')

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)
# Out:
# <AxesSubplot:>

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# # CONGRATULATIONS ON FINISHING THE PROJECT!

# %% [markdown]
# # APPENDIX

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
#
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }
